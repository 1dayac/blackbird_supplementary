# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


df_simulated = pd.DataFrame(columns = ["Method", "SV type",  "Recall", "Precision", "F1"])
df_simulated = df_simulated.append({"Method" : "Blackbird", "SV type" : "Deletions", "Precision" : 0.945, "Recall" : 0.733, "F1" : 0.826}, ignore_index = True)
df_simulated = df_simulated.append({"Method" : "SVaBa", "SV type" : "Deletions", "Precision" : 0.857, "Recall" : 0.129, "F1" : 0.224}, ignore_index = True)
df_simulated = df_simulated.append({"Method" : "Manta", "SV type" : "Deletions", "Precision" : 0.911, "Recall" : 0.617, "F1" : 0.736}, ignore_index = True)
df_simulated = df_simulated.append({"Method" : "Leviathan", "SV type" : "Deletions", "Precision" : 0.092, "Recall" : 0.007, "F1" : 0.013}, ignore_index = True)
df_simulated = df_simulated.append({"Method" : "Longranger", "SV type" : "Deletions", "Precision" : 0.958, "Recall" : 0.394, "F1" : 0.558}, ignore_index = True)


df_simulated = df_simulated.append({"Method" : "Blackbird", "SV type" : "Insertions", "Precision" : 0.943, "Recall" : 0.596, "F1" : 0.730}, ignore_index = True)
df_simulated = df_simulated.append({"Method" : "SVaBa", "SV type" : "Insertions", "Precision" : 0.287, "Recall" : 0.063, "F1" : 0.104}, ignore_index = True)
df_simulated = df_simulated.append({"Method" : "Manta", "SV type" : "Insertions", "Precision" : 0.765, "Recall" : 0.275, "F1" : 0.404}, ignore_index = True)
df_simulated = df_simulated.append({"Method" : "Leviathan", "SV type" : "Insertions", "Precision" : 0.109, "Recall" : 0.007, "F1" : 0.014}, ignore_index = True)


df_insertions = df_simulated[df_simulated["SV type"] == "Insertions"]
df_deletions = df_simulated[df_simulated["SV type"] == "Deletions"]

# %%
fig, axs = plt.subplots(1, 2, figsize =(20,10))

font = {'family' : 'normal',
        'size'   : 18}
plt.rc('font', **font)
plt.rcParams['figure.dpi'] = 400
df_deletions.set_index("Method").plot(kind = "bar", ax = axs[0], ylim=(0,1.0), yticks = np.arange(0, 1.01, 0.1), title = "Deletions", xlabel = "", rot = 0)
df_insertions.set_index("Method").plot(kind = "bar", ax= axs[1], ylim=(0, 1.0), yticks = np.arange(0, 1.01, 0.1), title = "Insertions", xlabel = "", rot = 0)
axs[0].get_legend().remove()

fig.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df_long = pd.DataFrame(columns = ["Method", "SV type", "Long-Read Coverage",   "Recall", "Precision",  "F1"])
#df_long = df_long.append({"Method" : "Blackbird", "SV type" : "Deletions", "Long-Read Coverage" : 0,  "Precision" : 0.945, "Recall" : 0.733, "F1" : 0.826}, ignore_index = True)
df_long = df_long.append({"Method" : "Blackbird", "SV type" : "Deletions", "Long-Read Coverage" : 5, "Precision" : 0.913, "Recall" : 0.858, "F1" : 0.869}, ignore_index = True)
df_long = df_long.append({"Method" : "Blackbird", "SV type" : "Deletions", "Long-Read Coverage" : 10, "Precision" : 0.896, "Recall" : 0.873, "F1" : 0.853}, ignore_index = True)
df_long = df_long.append({"Method" : "Blackbird", "SV type" : "Deletions", "Long-Read Coverage" : 15, "Precision" : 0.901, "Recall" : 0.864, "F1" : 0.852}, ignore_index = True)
df_long = df_long.append({"Method" : "Blackbird", "SV type" : "Deletions", "Long-Read Coverage" : 20, "Precision" : 0.900, "Recall" : 0.858, "F1" : 0.869}, ignore_index = True)
df_long = df_long.append({"Method" : "Blackbird", "SV type" : "Deletions", "Long-Read Coverage" : 25, "Precision" : 0.898, "Recall" : 0.858, "F1" : 0.853}, ignore_index = True)
df_long = df_long.append({"Method" : "Blackbird", "SV type" : "Deletions", "Long-Read Coverage" : 30, "Precision" : 0.884, "Recall" : 0.853, "F1" : 0.852}, ignore_index = True)
#df_long = df_long.append({"Method" : "Blackbird", "SV type" : "Insertions", "Long-Read Coverage" : 0, "Precision" : 0.943, "Recall" : 0.596, "F1" : 0.730}, ignore_index = True)
df_long = df_long.append({"Method" : "Blackbird", "SV type" : "Insertions", "Long-Read Coverage" : 5, "Precision" : 0.934, "Recall" : 0.746, "F1" : 0.833}, ignore_index = True)
df_long = df_long.append({"Method" : "Blackbird", "SV type" : "Insertions", "Long-Read Coverage" : 10, "Precision" : 0.929, "Recall" : 0.782, "F1" : 0.833}, ignore_index = True)
df_long = df_long.append({"Method" : "Blackbird", "SV type" : "Insertions", "Long-Read Coverage" : 15, "Precision" : 0.929, "Recall" : 0.785, "F1" : 0.833}, ignore_index = True)
df_long = df_long.append({"Method" : "Blackbird", "SV type" : "Insertions", "Long-Read Coverage" : 20, "Precision" : 0.932, "Recall" : 0.777, "F1" : 0.833}, ignore_index = True)
df_long = df_long.append({"Method" : "Blackbird", "SV type" : "Insertions", "Long-Read Coverage" : 25, "Precision" : 0.932, "Recall" : 0.773, "F1" : 0.833}, ignore_index = True)
df_long = df_long.append({"Method" : "Blackbird", "SV type" : "Insertions", "Long-Read Coverage" : 30, "Precision" : 0.936, "Recall" : 0.770, "F1" : 0.833}, ignore_index = True)

#df_long = df_long.append({"Method" : "PBSV", "SV type" : "Deletions", "Long-Read Coverage" : 0, "Precision" : 0.0, "Recall" : 0.0, "F1" : 0.0}, ignore_index = True)
df_long = df_long.append({"Method" : "PBSV", "SV type" : "Deletions", "Long-Read Coverage" : 5, "Precision" : 0.974, "Recall" : 0.651, "F1" : 0.781}, ignore_index = True)
df_long = df_long.append({"Method" : "PBSV", "SV type" : "Deletions", "Long-Read Coverage" : 10, "Precision" : 0.946, "Recall" : 0.791, "F1" : 0.862}, ignore_index = True)
df_long = df_long.append({"Method" : "PBSV", "SV type" : "Deletions", "Long-Read Coverage" : 15, "Precision" : 0.955, "Recall" : 0.813, "F1" : 0.878}, ignore_index = True)
df_long = df_long.append({"Method" : "PBSV", "SV type" : "Deletions", "Long-Read Coverage" : 20, "Precision" : 0.950, "Recall" : 0.815, "F1" : 0.781}, ignore_index = True)
df_long = df_long.append({"Method" : "PBSV", "SV type" : "Deletions", "Long-Read Coverage" : 25, "Precision" : 0.952, "Recall" : 0.817, "F1" : 0.862}, ignore_index = True)
df_long = df_long.append({"Method" : "PBSV", "SV type" : "Deletions", "Long-Read Coverage" : 30, "Precision" : 0.950, "Recall" : 0.813, "F1" : 0.878}, ignore_index = True)

#df_long = df_long.append({"Method" : "PBSV", "SV type" : "Insertions", "Long-Read Coverage" : 0, "Precision" : 0.0, "Recall" : 0.0, "F1" : 0.0}, ignore_index = True)
df_long = df_long.append({"Method" : "PBSV", "SV type" : "Insertions", "Long-Read Coverage" : 5, "Precision" : 0.920, "Recall" : 0.547, "F1" : 0.686}, ignore_index = True)
df_long = df_long.append({"Method" : "PBSV", "SV type" : "Insertions", "Long-Read Coverage" : 10, "Precision" : 0.918, "Recall" : 0.588, "F1" : 0.717}, ignore_index = True)
df_long = df_long.append({"Method" : "PBSV", "SV type" : "Insertions", "Long-Read Coverage" : 15, "Precision" : 0.899, "Recall" : 0.729, "F1" : 0.805}, ignore_index = True)
df_long = df_long.append({"Method" : "PBSV", "SV type" : "Insertions", "Long-Read Coverage" : 20, "Precision" : 0.880, "Recall" : 0.735, "F1" : 0.686}, ignore_index = True)
df_long = df_long.append({"Method" : "PBSV", "SV type" : "Insertions", "Long-Read Coverage" : 25, "Precision" : 0.872, "Recall" : 0.742, "F1" : 0.717}, ignore_index = True)
df_long = df_long.append({"Method" : "PBSV", "SV type" : "Insertions", "Long-Read Coverage" : 30, "Precision" : 0.879, "Recall" : 0.742, "F1" : 0.805}, ignore_index = True)

#df_long = df_long.append({"Method" : "Sniffles", "SV type" : "Deletions", "Long-Read Coverage" : 0, "Precision" : 0.0, "Recall" : 0.0, "F1" : 0.0}, ignore_index = True)
df_long = df_long.append({"Method" : "Sniffles", "SV type" : "Deletions", "Long-Read Coverage" : 5, "Precision" : 0.962, "Recall" : 0.763, "F1" : 0.851}, ignore_index = True)
df_long = df_long.append({"Method" : "Sniffles", "SV type" : "Deletions", "Long-Read Coverage" : 10, "Precision" : 0.942, "Recall" : 0.807, "F1" : 0.870}, ignore_index = True)
df_long = df_long.append({"Method" : "Sniffles", "SV type" : "Deletions", "Long-Read Coverage" : 15, "Precision" : 0.949, "Recall" : 0.809, "F1" : 0.873}, ignore_index = True)
df_long = df_long.append({"Method" : "Sniffles", "SV type" : "Deletions", "Long-Read Coverage" : 20, "Precision" : 0.942, "Recall" : 0.806, "F1" : 0.851}, ignore_index = True)
df_long = df_long.append({"Method" : "Sniffles", "SV type" : "Deletions", "Long-Read Coverage" : 25, "Precision" : 0.935, "Recall" : 0.808, "F1" : 0.870}, ignore_index = True)
df_long = df_long.append({"Method" : "Sniffles", "SV type" : "Deletions", "Long-Read Coverage" : 30, "Precision" : 0.938, "Recall" : 0.811, "F1" : 0.873}, ignore_index = True)

#df_long = df_long.append({"Method" : "Sniffles", "SV type" : "Insertions", "Long-Read Coverage" : 0, "Precision" : 0.0, "Recall" : 0.0, "F1" : 0.0}, ignore_index = True)
df_long = df_long.append({"Method" : "Sniffles", "SV type" : "Insertions", "Long-Read Coverage" : 5, "Precision" : 0.899, "Recall" : 0.631, "F1" : 0.741}, ignore_index = True)
df_long = df_long.append({"Method" : "Sniffles", "SV type" : "Insertions", "Long-Read Coverage" : 10, "Precision" : 0.892, "Recall" : 0.690, "F1" : 0.778}, ignore_index = True)
df_long = df_long.append({"Method" : "Sniffles", "SV type" : "Insertions", "Long-Read Coverage" : 15, "Precision" : 0.904, "Recall" : 0.691, "F1" : 0.784}, ignore_index = True)
df_long = df_long.append({"Method" : "Sniffles", "SV type" : "Insertions", "Long-Read Coverage" : 20, "Precision" : 0.902, "Recall" : 0.694, "F1" : 0.741}, ignore_index = True)
df_long = df_long.append({"Method" : "Sniffles", "SV type" : "Insertions", "Long-Read Coverage" : 25, "Precision" : 0.905, "Recall" : 0.690, "F1" : 0.778}, ignore_index = True)
df_long = df_long.append({"Method" : "Sniffles", "SV type" : "Insertions", "Long-Read Coverage" : 30, "Precision" : 0.905, "Recall" : 0.692, "F1" : 0.784}, ignore_index = True)

#df_0 = df_long[(df_long["Long-Read Coverage"] == 0) & (df_long["Method"] == "Blackbird")]
df_5 = df_long[(df_long["Long-Read Coverage"] == 5) & (df_long["Method"] == "Blackbird")]
df_10 = df_long[(df_long["Long-Read Coverage"] == 10) & (df_long["Method"] == "Blackbird")]
df_15 = df_long[(df_long["Long-Read Coverage"] == 15) & (df_long["Method"] == "Blackbird")]

#df_0_p = df_long[(df_long["Long-Read Coverage"] == 0) & (df_long["Method"] == "PBSV")]
df_5_p = df_long[(df_long["Long-Read Coverage"] == 5) & (df_long["Method"] == "PBSV")]
df_10_p = df_long[(df_long["Long-Read Coverage"] == 10) & (df_long["Method"] == "PBSV")]
df_15_p = df_long[(df_long["Long-Read Coverage"] == 15) & (df_long["Method"] == "PBSV")]

#df_0_s = df_long[(df_long["Long-Read Coverage"] == 0) & (df_long["Method"] == "Sniffles")]
df_5_s = df_long[(df_long["Long-Read Coverage"] == 5) & (df_long["Method"] == "Sniffles")]
df_10_s = df_long[(df_long["Long-Read Coverage"] == 10) & (df_long["Method"] == "Sniffles")]
df_15_s = df_long[(df_long["Long-Read Coverage"] == 15) & (df_long["Method"] == "Sniffles")]

#df_0 = df_0.drop('Long-Read Coverage', 1)
df_5 = df_5.drop('Long-Read Coverage', 1)
df_10 = df_10.drop('Long-Read Coverage', 1)
df_15 = df_15.drop('Long-Read Coverage', 1)
#df_0_p = df_0_p.drop('Long-Read Coverage', 1)
df_5_p = df_5_p.drop('Long-Read Coverage', 1)
df_10_p = df_10_p.drop('Long-Read Coverage', 1)
df_15_p = df_15_p.drop('Long-Read Coverage', 1)
#df_0_s = df_0_s.drop('Long-Read Coverage', 1)
df_5_s = df_5_s.drop('Long-Read Coverage', 1)
df_10_s = df_10_s.drop('Long-Read Coverage', 1)
df_15_s = df_15_s.drop('Long-Read Coverage', 1)
# Out:
# /var/folders/56/2rbdb8654tbdcvbn4dwlc9mc0000gt/T/ipykernel_1671/3412645729.py:69: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df_5 = df_5.drop('Long-Read Coverage', 1)
# /var/folders/56/2rbdb8654tbdcvbn4dwlc9mc0000gt/T/ipykernel_1671/3412645729.py:70: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df_10 = df_10.drop('Long-Read Coverage', 1)
# /var/folders/56/2rbdb8654tbdcvbn4dwlc9mc0000gt/T/ipykernel_1671/3412645729.py:71: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df_15 = df_15.drop('Long-Read Coverage', 1)
# ...

# %%
fig, axs = plt.subplots(3, 3, figsize =(20,10))
font = {'family' : 'normal',
        'size'   : 10}
plt.rc('font', **font)
plt.rcParams['figure.dpi'] = 400
#df_0.set_index("SV type").plot(kind = "bar", ylabel = "Blackbird", ax = axs[0][0], ylim=(0,1.0), yticks = np.arange(0, 1.01, 0.1), title = "Long read coverage = 0", xlabel = "", rot = 0)
df_5.set_index("SV type").plot(kind = "bar", ylabel = "Blackbird", ax= axs[0][0], ylim=(0, 1.0), yticks = np.arange(0, 1.01, 0.1), title = "Long read coverage = 5", xlabel = "", rot = 0)
df_10.set_index("SV type").plot(kind = "bar", ax= axs[0][1], ylim=(0, 1.0), yticks = np.arange(0, 1.01, 0.1), title = "Long read coverage = 10", xlabel = "", rot = 0)
df_15.set_index("SV type").plot(kind = "bar", ax= axs[0][2], ylim=(0, 1.0), yticks = np.arange(0, 1.01, 0.1), title = "Long read coverage = 15", xlabel = "", rot = 0)
#df_0_p.plot(kind = "bar", ax= axs[1][0], xticks = [], ylabel = "PBSV", ylim=(0, 1.0), yticks = np.arange(0, 1.01, 0.1), xlabel = "", rot = 0)
df_5_p.set_index("SV type").plot(kind = "bar", ylabel = "PBSV", ax= axs[1][0], ylim=(0, 1.0), yticks = np.arange(0, 1.01, 0.1), xlabel = "", rot = 0)
df_10_p.set_index("SV type").plot(kind = "bar", ax= axs[1][1], ylim=(0, 1.0), yticks = np.arange(0, 1.01, 0.1), xlabel = "", rot = 0)
df_15_p.set_index("SV type").plot(kind = "bar", ax= axs[1][2], ylim=(0, 1.0), yticks = np.arange(0, 1.01, 0.1), xlabel = "", rot = 0)
#df_0_s.plot(kind = "bar", ax= axs[2][0], xticks = [], ylabel = "Sniffles", ylim=(0, 1.0), yticks = np.arange(0, 1.01, 0.1), xlabel = "", rot = 0)
df_5_s.set_index("SV type").plot(kind = "bar", ax= axs[2][0], ylabel = "Sniffles", ylim=(0, 1.0), yticks = np.arange(0, 1.01, 0.1), xlabel = "", rot = 0)
df_10_s.set_index("SV type").plot(kind = "bar", ax= axs[2][1], ylim=(0, 1.0), yticks = np.arange(0, 1.01, 0.1), xlabel = "", rot = 0)
df_15_s.set_index("SV type").plot(kind = "bar", ax= axs[2][2], ylim=(0, 1.0), yticks = np.arange(0, 1.01, 0.1), xlabel = "", rot = 0)


axs[0][0].get_legend().remove()
axs[0][1].get_legend().remove()
axs[0][2].get_legend().remove()
axs[1][0].get_legend().remove()
axs[1][1].get_legend().remove()
axs[1][2].get_legend().remove()
#axs[1][3].get_legend().remove()
axs[2][1].get_legend().remove()
axs[2][2].get_legend().remove()
#axs[2][3].get_legend().remove()

for ax_vector in axs:
    for ax in ax_vector:
        for container in ax.containers:
            ax.bar_label(container)


fig.show()

# %%
fig, axs = plt.subplots(2, 3, figsize =(20,10))
font = {'family' : 'normal',
        'size'   : 10}
plt.rc('font', **font)
plt.rcParams['figure.dpi'] = 400


df_5 = df_long[(df_long["Long-Read Coverage"] == 5)]
df_10 = df_long[(df_long["Long-Read Coverage"] == 10)]
df_15 = df_long[(df_long["Long-Read Coverage"] == 15)]
df_20 = df_long[(df_long["Long-Read Coverage"] == 20)]
df_25 = df_long[(df_long["Long-Read Coverage"] == 25)]
df_30 = df_long[(df_long["Long-Read Coverage"] == 30)]
print(df_15)

df_5.plot(kind = "bar", ylabel = "Blackbird", ax= axs[0][0], ylim=(0, 1.0), yticks = np.arange(0, 1.01, 0.1), title = "Long read coverage = 5", xlabel = "", rot = 0)
df_10.plot(kind = "bar", ax= axs[0][1], ylim=(0, 1.0), yticks = np.arange(0, 1.01, 0.1), title = "Long read coverage = 10", xlabel = "", rot = 0)
#df_15.set_index("Method").plot(kind = "scatter",x = "Precision", y = "Recall", c = [df_15['SV type']], ax= axs[0][2], ylim=(0, 1.0), yticks = np.arange(0, 1.01, 0.1), title = "Long read coverage = 15", xlabel = "", rot = 0)
#df_20.set_index("SV type").plot(kind = "bar", ylabel = "PBSV", ax= axs[1][0], ylim=(0, 1.0), yticks = np.arange(0, 1.01, 0.1), title = "Long read coverage = 20", xlabel = "", rot = 0)
#df_25.set_index("SV type").plot(kind = "bar", ax= axs[1][1], ylim=(0, 1.0), yticks = np.arange(0, 1.01, 0.1), title = "Long read coverage = 25", xlabel = "", rot = 0)
#df_30.set_index("SV type").plot(kind = "bar", ax= axs[1][2], ylim=(0, 1.0), yticks = np.arange(0, 1.01, 0.1), title = "Long read coverage = 30", xlabel = "", rot = 0)


colors = {'Insertions' : 'red', 'Deletions':'blue'}
d = {"Sniffles" : 'd', "Blackbird" : 's', "PBSV" : 'p'}
groups = df_15.groupby('Method')
dd = {}
for name, group in groups:
    print(name)
    dd[name] = axs[0][2].scatter(group.Precision, group.Recall, marker = d[name], c = group["SV type"].map(colors), label = d[name])

axs[0][2].legend((dd["Blackbird"], dd["PBSV"], dd["Sniffles"]), ('Blackbird', 'PBSV', 'Sniffles'), loc='lower right')
axs[0][2].get_legend().legendHandles[0].set_color('green')
axs[0][2].get_legend().legendHandles[1].set_color('green')
axs[0][2].get_legend().legendHandles[2].set_color('green')

#for name, group in groups:
#    axs[0][2].plot(group.Precision, group.Recall, marker='o', linestyle='', xlim=(0.5,1.0), ylim=(0.5,1.0), ms=12, label=name)
#axs[0][2].legend()

axs[0][0].get_legend().remove()
axs[0][1].get_legend().remove()
#axs[0][2].get_legend().remove()
#axs[1][0].get_legend().remove()
#axs[1][1].get_legend().remove()
#axs[1][2].get_legend().remove()

for ax_vector in axs:
    for ax in ax_vector:
        for container in ax.containers:
            ax.bar_label(container)


fig.show()

# %%
fig, axs = plt.subplots(1, 2, figsize =(20,10))
font = {'family' : 'normal',
        'size'   : 10}
plt.rc('font', **font)
plt.rcParams['figure.dpi'] = 400


df_ins = df_long[(df_long["SV type"] == "Insertions")]
df_del = df_long[(df_long["SV type"] == "Deletions")]
colors = {'Blackbird' : 'red', 'Sniffles2':'blue', "PBSV" : 'green'}
marker = {5 : 'd', 10 : 's', 15 : 'p', 20 : '<', 25 : '>', 30 : 'P'}
print(df_ins)
groups = df_ins.groupby('Long-Read Coverage')
dd = {}
for name, group in groups:
    print(name)
    axs[1].scatter(group.Precision, group.Recall, marker = marker[name], c = group["Long-Read Coverage"].map(colors))

#axs[0][2].legend((dd["Blackbird"], dd["PBSV"], dd["Sniffles"]), ('Blackbird', 'PBSV', 'Sniffles'), loc='lower right')
fig.show()

# %%
fig, axs = plt.subplots(2, 3, figsize =(20,10))
font = {'family' : 'normal',
        'size'   : 10}
plt.rc('font', **font)
plt.rcParams['figure.dpi'] = 400


df_5 = df_long[(df_long["Long-Read Coverage"] == 5)]
df_10 = df_long[(df_long["Long-Read Coverage"] == 10)]
df_15 = df_long[(df_long["Long-Read Coverage"] == 15)]
df_20 = df_long[(df_long["Long-Read Coverage"] == 20)]
df_25 = df_long[(df_long["Long-Read Coverage"] == 25)]
df_30 = df_long[(df_long["Long-Read Coverage"] == 30)]
print(df_15)

df_5.plot(kind = "bar", ylabel = "Blackbird", ax= axs[0][0], ylim=(0, 1.0), yticks = np.arange(0, 1.01, 0.1), title = "Long read coverage = 5", xlabel = "", rot = 0)
df_10.plot(kind = "bar", ax= axs[0][1], ylim=(0, 1.0), yticks = np.arange(0, 1.01, 0.1), title = "Long read coverage = 10", xlabel = "", rot = 0)
#df_15.set_index("Method").plot(kind = "scatter",x = "Precision", y = "Recall", c = [df_15['SV type']], ax= axs[0][2], ylim=(0, 1.0), yticks = np.arange(0, 1.01, 0.1), title = "Long read coverage = 15", xlabel = "", rot = 0)
#df_20.set_index("SV type").plot(kind = "bar", ylabel = "PBSV", ax= axs[1][0], ylim=(0, 1.0), yticks = np.arange(0, 1.01, 0.1), title = "Long read coverage = 20", xlabel = "", rot = 0)
#df_25.set_index("SV type").plot(kind = "bar", ax= axs[1][1], ylim=(0, 1.0), yticks = np.arange(0, 1.01, 0.1), title = "Long read coverage = 25", xlabel = "", rot = 0)
#df_30.set_index("SV type").plot(kind = "bar", ax= axs[1][2], ylim=(0, 1.0), yticks = np.arange(0, 1.01, 0.1), title = "Long read coverage = 30", xlabel = "", rot = 0)


colors = {'Insertions' : 'red', 'Deletions':'blue'}
d = {"Sniffles" : 'd', "Blackbird" : 's', "PBSV" : 'p'}
groups = df_15.groupby('Method')
dd = {}
for name, group in groups:
    print(name)
    dd[name] = axs[0][2].scatter(group.Precision, group.Recall, marker = d[name], c = group["SV type"].map(colors), label = d[name])

axs[0][2].legend((dd["Blackbird"], dd["PBSV"], dd["Sniffles"]), ('Blackbird', 'PBSV', 'Sniffles'), loc='lower right')
axs[0][2].get_legend().legendHandles[0].set_color('green')
axs[0][2].get_legend().legendHandles[1].set_color('green')
axs[0][2].get_legend().legendHandles[2].set_color('green')

#for name, group in groups:
#    axs[0][2].plot(group.Precision, group.Recall, marker='o', linestyle='', xlim=(0.5,1.0), ylim=(0.5,1.0), ms=12, label=name)
#axs[0][2].legend()

axs[0][0].get_legend().remove()
axs[0][1].get_legend().remove()
#axs[0][2].get_legend().remove()
#axs[1][0].get_legend().remove()
#axs[1][1].get_legend().remove()
#axs[1][2].get_legend().remove()

for ax_vector in axs:
    for ax in ax_vector:
        for container in ax.containers:
            ax.bar_label(container)


fig.show()

# %%
fig, axs = plt.subplots(1, 2, figsize =(20,10))
font = {'family' : 'normal',
        'size'   : 10}
plt.rc('font', **font)
plt.rcParams['figure.dpi'] = 400


df_ins = df_long[(df_long["SV type"] == "Insertions")]
df_del = df_long[(df_long["SV type"] == "Deletions")]
colors = {'Blackbird' : 'red', 'Sniffles':'blue', "PBSV" : 'green'}
marker = {5 : 'd', 10 : 's', 15 : 'p', 20 : '<', 25 : '>', 30 : 'P'}

groups = df_ins.groupby("Long-Read Coverage")

dd = {}
for name, group in groups:
    print(group)
    #dd[name] = axs[1].scatter(group.Precision, group.Recall, marker = d[name], c = group["SV type"].map(colors), label = d[name])
    dd[name] = axs[1].scatter(group.Precision, group.Recall, marker = marker[name], c = group["Method"].map(colors))
axs[1].set_ylim((0.5,1))
axs[1].set_xlim((0.7,1))
axs[1].set_xlabel("Precision")
axs[1].set_ylabel("Recall")
axs[1].set_title("Insertions")
from matplotlib.legend import Legend

axs[1].legend((dd[5], dd[10], dd[15], dd[20], dd[25], dd[30]), ('5', '10', '15', '20', '25', '30'), title = "Long read coverage", loc='lower right')
from matplotlib.lines import Line2D
#axs[1].legend(('Blackbird', 'PBSV', 'Sniffles'), loc='upper right')
legend_elements = [Line2D([0], [0], marker='o', color='w', label='Blackbird',
                          markerfacecolor='red', markersize=15),
                           Line2D([0], [0], marker='o', color='w', label='PBSV',
                          markerfacecolor='g', markersize=15),
                           Line2D([0], [0], marker='o', color='w', label='Sniffles',
                          markerfacecolor='blue', markersize=15)]
axs[1].add_artist(Legend(axs[1],title = "Methods", handles=legend_elements, labels = ["Blackbird", "PBSV", "Sniffles"], loc = 'upper right'))

axs[1].get_legend().legendHandles[0].set_color('black')
axs[1].get_legend().legendHandles[1].set_color('black')
axs[1].get_legend().legendHandles[2].set_color('black')
axs[1].get_legend().legendHandles[3].set_color('black')
axs[1].get_legend().legendHandles[4].set_color('black')
axs[1].get_legend().legendHandles[5].set_color('black')


groups = df_del.groupby("Long-Read Coverage")

dd = {}
for name, group in groups:
    print(group)
    #dd[name] = axs[1].scatter(group.Precision, group.Recall, marker = d[name], c = group["SV type"].map(colors), label = d[name])
    dd[name] = axs[0].scatter(group.Precision, group.Recall, marker = marker[name], c = group["Method"].map(colors))
axs[0].set_ylim((0.5,1))
axs[0].set_xlim((0.7,1))
axs[0].set_xlabel("Precision")
axs[0].set_ylabel("Recall")
axs[0].set_title("Deletions")
# Out:
#        Method     SV type Long-Read Coverage  Recall  Precision     F1
# 6   Blackbird  Insertions                  5   0.746      0.934  0.833
# 18       PBSV  Insertions                  5   0.547      0.920  0.686
# 30   Sniffles  Insertions                  5   0.631      0.899  0.741
#        Method     SV type Long-Read Coverage  Recall  Precision     F1
# 7   Blackbird  Insertions                 10   0.782      0.929  0.833
# 19       PBSV  Insertions                 10   0.588      0.918  0.717
# 31   Sniffles  Insertions                 10   0.690      0.892  0.778
#        Method     SV type Long-Read Coverage  Recall  Precision     F1
# 8   Blackbird  Insertions                 15   0.785      0.929  0.833
# 20       PBSV  Insertions                 15   0.729      0.899  0.805
# 32   Sniffles  Insertions                 15   0.691      0.904  0.784
#        Method     SV type Long-Read Coverage  Recall  Precision     F1
# ...

# %%
group["Method"].map(colors)

# %%
fig, axs = plt.subplots(2, 3, figsize =(20,10))
font = {'family' : 'normal',
        'size'   : 10}
plt.rc('font', **font)
plt.rcParams['figure.dpi'] = 400


df_5 = df_long[(df_long["Long-Read Coverage"] == 5)]
df_10 = df_long[(df_long["Long-Read Coverage"] == 10)]
df_15 = df_long[(df_long["Long-Read Coverage"] == 15)]
df_20 = df_long[(df_long["Long-Read Coverage"] == 20)]
df_25 = df_long[(df_long["Long-Read Coverage"] == 25)]
df_30 = df_long[(df_long["Long-Read Coverage"] == 30)]
print(df_15)

df_5.plot(kind = "bar", ylabel = "Blackbird", ax= axs[0][0], ylim=(0, 1.0), yticks = np.arange(0, 1.01, 0.1), title = "Long read coverage = 5", xlabel = "", rot = 0)
df_10.plot(kind = "bar", ax= axs[0][1], ylim=(0, 1.0), yticks = np.arange(0, 1.01, 0.1), title = "Long read coverage = 10", xlabel = "", rot = 0)
#df_15.set_index("Method").plot(kind = "scatter",x = "Precision", y = "Recall", c = [df_15['SV type']], ax= axs[0][2], ylim=(0, 1.0), yticks = np.arange(0, 1.01, 0.1), title = "Long read coverage = 15", xlabel = "", rot = 0)
#df_20.set_index("SV type").plot(kind = "bar", ylabel = "PBSV", ax= axs[1][0], ylim=(0, 1.0), yticks = np.arange(0, 1.01, 0.1), title = "Long read coverage = 20", xlabel = "", rot = 0)
#df_25.set_index("SV type").plot(kind = "bar", ax= axs[1][1], ylim=(0, 1.0), yticks = np.arange(0, 1.01, 0.1), title = "Long read coverage = 25", xlabel = "", rot = 0)
#df_30.set_index("SV type").plot(kind = "bar", ax= axs[1][2], ylim=(0, 1.0), yticks = np.arange(0, 1.01, 0.1), title = "Long read coverage = 30", xlabel = "", rot = 0)


colors = {'Insertions' : 'red', 'Deletions':'blue'}
d = {"Sniffles" : 'd', "Blackbird" : 's', "PBSV" : 'p'}
groups = df_15.groupby('Method')
dd = {}
for name, group in groups:
    print(name)
    dd[name] = axs[0][2].scatter(group.Precision, group.Recall, marker = d[name], c = group["SV type"].map(colors), label = d[name])

axs[0][2].legend((dd["Blackbird"], dd["PBSV"], dd["Sniffles"]), ('Blackbird', 'PBSV', 'Sniffles'), loc='lower right')
axs[0][2].get_legend().legendHandles[0].set_color('green')
axs[0][2].get_legend().legendHandles[1].set_color('green')
axs[0][2].get_legend().legendHandles[2].set_color('green')

#for name, group in groups:
#    axs[0][2].plot(group.Precision, group.Recall, marker='o', linestyle='', xlim=(0.5,1.0), ylim=(0.5,1.0), ms=12, label=name)
#axs[0][2].legend()

axs[0][0].get_legend().remove()
axs[0][1].get_legend().remove()
#axs[0][2].get_legend().remove()
#axs[1][0].get_legend().remove()
#axs[1][1].get_legend().remove()
#axs[1][2].get_legend().remove()

for ax_vector in axs:
    for ax in ax_vector:
        for container in ax.containers:
            ax.bar_label(container)


fig.show()

# %%
fig, axs = plt.subplots(1, 2, figsize =(20,10))
font = {'family' : 'normal',
        'size'   : 10}
plt.rc('font', **font)
plt.rcParams['figure.dpi'] = 400


df_ins = df_long[(df_long["Long-Read Coverage"] == "Insertions")]
df_del = df_long[(df_long["Long-Read Coverage"] == "Deletions")]
colors = {'Blackbird' : 'red', 'Sniffles2':'blue', "PBSV" : 'green'}
marker = {5 : 'd', 10 : 's', 15 : 'p', 20 : '<', 25 : '>', 30 : 'P'}

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df_hg002 = pd.DataFrame(columns = ["Method", "SV type", "Long-Read Coverage",   "Recall", "Precision",  "F1"])
df_hg002 = df_hg002.append({"Method" : "Blackbird", "SV type" : "Deletions", "Long-Read Coverage" : 5, "Precision" : 0.860, "Recall" : 0.793, "F1" : 0.826}, ignore_index = True)
df_hg002 = df_hg002.append({"Method" : "Blackbird", "SV type" : "Deletions", "Long-Read Coverage" : 10, "Precision" : 0.866, "Recall" : 0.829, "F1" : 0.853}, ignore_index = True)
df_hg002 = df_hg002.append({"Method" : "Blackbird", "SV type" : "Deletions", "Long-Read Coverage" : 20, "Precision" : 0.883, "Recall" : 0.838, "F1" : 0.860}, ignore_index = True)
df_hg002 = df_hg002.append({"Method" : "Blackbird", "SV type" : "Deletions", "Long-Read Coverage" : 34, "Precision" : 0.876, "Recall" : 0.850, "F1" : 0.863}, ignore_index = True)

df_hg002 = df_hg002.append({"Method" : "Blackbird", "SV type" : "Insertions", "Long-Read Coverage" : 5, "Precision" : 0.935, "Recall" : 0.713, "F1" : 0.809}, ignore_index = True)
df_hg002 = df_hg002.append({"Method" : "Blackbird", "SV type" : "Insertions", "Long-Read Coverage" : 10, "Precision" : 0.944, "Recall" : 0.738, "F1" : 0.828}, ignore_index = True)
df_hg002 = df_hg002.append({"Method" : "Blackbird", "SV type" : "Insertions", "Long-Read Coverage" : 20, "Precision" : 0.892, "Recall" : 0.755, "F1" : 0.817}, ignore_index = True)
df_hg002 = df_hg002.append({"Method" : "Blackbird", "SV type" : "Insertions", "Long-Read Coverage" : 34, "Precision" : 0.900, "Recall" : 0.736, "F1" : 0.809}, ignore_index = True)


df_hg002= df_hg002.append({"Method" : "PBSV", "SV type" : "Deletions", "Long-Read Coverage" : 5, "Precision" : 0.906, "Recall" : 0.694, "F1" : 0.786}, ignore_index = True)
df_hg002= df_hg002.append({"Method" : "PBSV", "SV type" : "Deletions", "Long-Read Coverage" : 10, "Precision" : 0.906, "Recall" : 0.812, "F1" : 0.857}, ignore_index = True)
df_hg002= df_hg002.append({"Method" : "PBSV", "SV type" : "Deletions", "Long-Read Coverage" : 20, "Precision" : 0.905, "Recall" : 0.832, "F1" : 0.866}, ignore_index = True)
df_hg002= df_hg002.append({"Method" : "PBSV", "SV type" : "Deletions", "Long-Read Coverage" : 34, "Precision" : 0.905, "Recall" : 0.836, "F1" : 0.869}, ignore_index = True)

df_hg002 = df_hg002.append({"Method" : "PBSV", "SV type" : "Insertions", "Long-Read Coverage" : 5, "Precision" : 0.924, "Recall" : 0.617, "F1" : 0.738}, ignore_index = True)
df_hg002 = df_hg002.append({"Method" : "PBSV", "SV type" : "Insertions", "Long-Read Coverage" : 10, "Precision" : 0.913, "Recall" : 0.731, "F1" : 0.812}, ignore_index = True)
df_hg002 = df_hg002.append({"Method" : "PBSV", "SV type" : "Insertions", "Long-Read Coverage" : 20, "Precision" : 0.915, "Recall" : 0.753, "F1" : 0.826}, ignore_index = True)
df_hg002 = df_hg002.append({"Method" : "PBSV", "SV type" : "Insertions", "Long-Read Coverage" : 34, "Precision" : 0.912, "Recall" : 0.756, "F1" : 0.827}, ignore_index = True)

df_hg002 = df_hg002.append({"Method" : "Sniffles", "SV type" : "Deletions", "Long-Read Coverage" : 5, "Precision" : 0.886, "Recall" : 0.688, "F1" : 0.774}, ignore_index = True)
df_hg002 = df_hg002.append({"Method" : "Sniffles", "SV type" : "Deletions", "Long-Read Coverage" : 10, "Precision" : 0.888, "Recall" : 0.796, "F1" : 0.839}, ignore_index = True)
df_hg002 = df_hg002.append({"Method" : "Sniffles", "SV type" : "Deletions", "Long-Read Coverage" : 20, "Precision" : 0.884, "Recall" : 0.834, "F1" : 0.858}, ignore_index = True)
df_hg002 = df_hg002.append({"Method" : "Sniffles", "SV type" : "Deletions", "Long-Read Coverage" : 34, "Precision" : 0.885, "Recall" : 0.840, "F1" : 0.862}, ignore_index = True)

df_hg002 = df_hg002.append({"Method" : "Sniffles", "SV type" : "Insertions", "Long-Read Coverage" : 5, "Precision" : 0.920, "Recall" : 0.622, "F1" : 0.742}, ignore_index = True)
df_hg002 = df_hg002.append({"Method" : "Sniffles", "SV type" : "Insertions", "Long-Read Coverage" : 10, "Precision" : 0.912, "Recall" : 0.719, "F1" : 0.804}, ignore_index = True)
df_hg002 = df_hg002.append({"Method" : "Sniffles", "SV type" : "Insertions", "Long-Read Coverage" : 20, "Precision" : 0.904, "Recall" : 0.740, "F1" : 0.814}, ignore_index = True)
df_hg002 = df_hg002.append({"Method" : "Sniffles", "SV type" : "Insertions", "Long-Read Coverage" : 34, "Precision" : 0.903, "Recall" : 0.744, "F1" : 0.816}, ignore_index = True)

# %%
fig, axs = plt.subplots(1, 2, figsize =(20,10))
font = {'family' : 'normal',
        'size'   : 10}
plt.rc('font', **font)
plt.rcParams['figure.dpi'] = 400


df_ins = df_hg002[(df_hg002["SV type"] == "Insertions")]
df_del = df_hg002[(df_hg002["SV type"] == "Deletions")]
colors = {'Blackbird' : 'red', 'Sniffles':'blue', "PBSV" : 'green'}
marker = {5 : 'd', 10 : 's', 20 : '<', 34 : '>'}


groups = df_ins.groupby("Long-Read Coverage")

dd = {}
for name, group in groups:
    print(group)
    #dd[name] = axs[1].scatter(group.Precision, group.Recall, marker = d[name], c = group["SV type"].map(colors), label = d[name])
    dd[name] = axs[1].scatter(group.Precision, group.Recall, marker = marker[name], c = group["Method"].map(colors))
axs[1].set_ylim((0.5,1))
axs[1].set_xlim((0.7,1))
axs[1].set_xlabel("Precision")
axs[1].set_ylabel("Recall")
axs[1].set_title("Insertions")
from matplotlib.legend import Legend

axs[1].legend((dd[5], dd[10], dd[20], dd[34]), ('5', '10', '20', '34'), title = "Long read coverage", loc='lower right')
from matplotlib.lines import Line2D
#axs[1].legend(('Blackbird', 'PBSV', 'Sniffles'), loc='upper right')
legend_elements = [Line2D([0], [0], marker='o', color='w', label='Blackbird',
                          markerfacecolor='red', markersize=15),
                           Line2D([0], [0], marker='o', color='w', label='PBSV',
                          markerfacecolor='g', markersize=15),
                           Line2D([0], [0], marker='o', color='w', label='Sniffles',
                          markerfacecolor='blue', markersize=15)]
axs[1].add_artist(Legend(axs[1],title = "Methods", handles=legend_elements, labels = ["Blackbird", "PBSV", "Sniffles"], loc = 'upper right'))

axs[1].get_legend().legendHandles[0].set_color('black')
axs[1].get_legend().legendHandles[1].set_color('black')
axs[1].get_legend().legendHandles[2].set_color('black')
axs[1].get_legend().legendHandles[3].set_color('black')
#axs[1].get_legend().legendHandles[4].set_color('black')
#axs[1].get_legend().legendHandles[5].set_color('black')


groups = df_del.groupby("Long-Read Coverage")

dd = {}
for name, group in groups:
    print(group)
    #dd[name] = axs[1].scatter(group.Precision, group.Recall, marker = d[name], c = group["SV type"].map(colors), label = d[name])
    dd[name] = axs[0].scatter(group.Precision, group.Recall, marker = marker[name], c = group["Method"].map(colors))
axs[0].set_ylim((0.5,1))
axs[0].set_xlim((0.7,1))
axs[0].set_xlabel("Precision")
axs[0].set_ylabel("Recall")
axs[0].set_title("Deletions")

# %%
group["Method"].map(colors)

# %%
fig, axs = plt.subplots(2, 3, figsize =(20,10))
font = {'family' : 'normal',
        'size'   : 10}
plt.rc('font', **font)
plt.rcParams['figure.dpi'] = 400


df_5 = df_long[(df_long["Long-Read Coverage"] == 5)]
df_10 = df_long[(df_long["Long-Read Coverage"] == 10)]
df_15 = df_long[(df_long["Long-Read Coverage"] == 15)]
df_20 = df_long[(df_long["Long-Read Coverage"] == 20)]
df_25 = df_long[(df_long["Long-Read Coverage"] == 25)]
df_30 = df_long[(df_long["Long-Read Coverage"] == 30)]
print(df_15)

df_5.plot(kind = "bar", ylabel = "Blackbird", ax= axs[0][0], ylim=(0, 1.0), yticks = np.arange(0, 1.01, 0.1), title = "Long read coverage = 5", xlabel = "", rot = 0)
df_10.plot(kind = "bar", ax= axs[0][1], ylim=(0, 1.0), yticks = np.arange(0, 1.01, 0.1), title = "Long read coverage = 10", xlabel = "", rot = 0)
#df_15.set_index("Method").plot(kind = "scatter",x = "Precision", y = "Recall", c = [df_15['SV type']], ax= axs[0][2], ylim=(0, 1.0), yticks = np.arange(0, 1.01, 0.1), title = "Long read coverage = 15", xlabel = "", rot = 0)
#df_20.set_index("SV type").plot(kind = "bar", ylabel = "PBSV", ax= axs[1][0], ylim=(0, 1.0), yticks = np.arange(0, 1.01, 0.1), title = "Long read coverage = 20", xlabel = "", rot = 0)
#df_25.set_index("SV type").plot(kind = "bar", ax= axs[1][1], ylim=(0, 1.0), yticks = np.arange(0, 1.01, 0.1), title = "Long read coverage = 25", xlabel = "", rot = 0)
#df_30.set_index("SV type").plot(kind = "bar", ax= axs[1][2], ylim=(0, 1.0), yticks = np.arange(0, 1.01, 0.1), title = "Long read coverage = 30", xlabel = "", rot = 0)


colors = {'Insertions' : 'red', 'Deletions':'blue'}
d = {"Sniffles" : 'd', "Blackbird" : 's', "PBSV" : 'p'}
groups = df_15.groupby('Method')
dd = {}
for name, group in groups:
    print(name)
    dd[name] = axs[0][2].scatter(group.Precision, group.Recall, marker = d[name], c = group["SV type"].map(colors), label = d[name])

axs[0][2].legend((dd["Blackbird"], dd["PBSV"], dd["Sniffles"]), ('Blackbird', 'PBSV', 'Sniffles'), loc='lower right')
axs[0][2].get_legend().legendHandles[0].set_color('green')
axs[0][2].get_legend().legendHandles[1].set_color('green')
axs[0][2].get_legend().legendHandles[2].set_color('green')

#for name, group in groups:
#    axs[0][2].plot(group.Precision, group.Recall, marker='o', linestyle='', xlim=(0.5,1.0), ylim=(0.5,1.0), ms=12, label=name)
#axs[0][2].legend()

axs[0][0].get_legend().remove()
axs[0][1].get_legend().remove()
#axs[0][2].get_legend().remove()
#axs[1][0].get_legend().remove()
#axs[1][1].get_legend().remove()
#axs[1][2].get_legend().remove()

for ax_vector in axs:
    for ax in ax_vector:
        for container in ax.containers:
            ax.bar_label(container)


fig.show()

# %%
fig, axs = plt.subplots(1, 2, figsize =(20,10))
font = {'family' : 'normal',
        'size'   : 10}
plt.rc('font', **font)
plt.rcParams['figure.dpi'] = 400


df_ins = df_long[(df_long["Long-Read Coverage"] == "Insertions")]
df_del = df_long[(df_long["Long-Read Coverage"] == "Deletions")]
colors = {'Blackbird' : 'red', 'Sniffles2':'blue', "PBSV" : 'green'}
marker = {5 : 'd', 10 : 's', 15 : 'p', 20 : '<', 25 : '>', 30 : 'P'}

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df_hg002 = pd.DataFrame(columns = ["Method", "SV type", "Long-Read Coverage",   "Recall", "Precision",  "F1"])
df_hg002 = df_hg002.append({"Method" : "Blackbird", "SV type" : "Deletions", "Long-Read Coverage" : 5, "Precision" : 0.860, "Recall" : 0.793, "F1" : 0.826}, ignore_index = True)
df_hg002 = df_hg002.append({"Method" : "Blackbird", "SV type" : "Deletions", "Long-Read Coverage" : 10, "Precision" : 0.866, "Recall" : 0.829, "F1" : 0.853}, ignore_index = True)
df_hg002 = df_hg002.append({"Method" : "Blackbird", "SV type" : "Insertions", "Long-Read Coverage" : 5, "Precision" : 0.935, "Recall" : 0.713, "F1" : 0.809}, ignore_index = True)
df_hg002 = df_hg002.append({"Method" : "Blackbird", "SV type" : "Insertions", "Long-Read Coverage" : 10, "Precision" : 0.944, "Recall" : 0.738, "F1" : 0.828}, ignore_index = True)


df_hg002= df_hg002.append({"Method" : "PBSV", "SV type" : "Deletions", "Long-Read Coverage" : 5, "Precision" : 0.906, "Recall" : 0.694, "F1" : 0.786}, ignore_index = True)
df_hg002= df_hg002.append({"Method" : "PBSV", "SV type" : "Deletions", "Long-Read Coverage" : 10, "Precision" : 0.906, "Recall" : 0.812, "F1" : 0.857}, ignore_index = True)
df_hg002 = df_hg002.append({"Method" : "PBSV", "SV type" : "Insertions", "Long-Read Coverage" : 5, "Precision" : 0.924, "Recall" : 0.617, "F1" : 0.738}, ignore_index = True)
df_hg002 = df_hg002.append({"Method" : "PBSV", "SV type" : "Insertions", "Long-Read Coverage" : 10, "Precision" : 0.913, "Recall" : 0.731, "F1" : 0.812}, ignore_index = True)

df_hg002 = df_hg002.append({"Method" : "Sniffles", "SV type" : "Deletions", "Long-Read Coverage" : 5, "Precision" : 0.886, "Recall" : 0.688, "F1" : 0.774}, ignore_index = True)
df_hg002 = df_hg002.append({"Method" : "Sniffles", "SV type" : "Deletions", "Long-Read Coverage" : 10, "Precision" : 0.888, "Recall" : 0.796, "F1" : 0.839}, ignore_index = True)

df_hg002 = df_hg002.append({"Method" : "Sniffles", "SV type" : "Insertions", "Long-Read Coverage" : 5, "Precision" : 0.920, "Recall" : 0.622, "F1" : 0.742}, ignore_index = True)
df_hg002 = df_hg002.append({"Method" : "Sniffles", "SV type" : "Insertions", "Long-Read Coverage" : 10, "Precision" : 0.912, "Recall" : 0.719, "F1" : 0.804}, ignore_index = True)

# %%
fig, axs = plt.subplots(1, 2, figsize =(20,10))
font = {'family' : 'normal',
        'size'   : 10}
plt.rc('font', **font)
plt.rcParams['figure.dpi'] = 400


df_ins = df_hg002[(df_hg002["SV type"] == "Insertions")]
df_del = df_hg002[(df_hg002["SV type"] == "Deletions")]
colors = {'Blackbird' : 'red', 'Sniffles':'blue', "PBSV" : 'green'}
marker = {5 : 'd', 10 : 's', 20 : '<', 34 : '>'}


groups = df_ins.groupby("Long-Read Coverage")

dd = {}
for name, group in groups:
    print(group)
    #dd[name] = axs[1].scatter(group.Precision, group.Recall, marker = d[name], c = group["SV type"].map(colors), label = d[name])
    dd[name] = axs[1].scatter(group.Precision, group.Recall, marker = marker[name], c = group["Method"].map(colors))
axs[1].set_ylim((0.5,1))
axs[1].set_xlim((0.7,1))
axs[1].set_xlabel("Precision")
axs[1].set_ylabel("Recall")
axs[1].set_title("Insertions")
from matplotlib.legend import Legend

axs[1].legend((dd[5], dd[10], dd[20], dd[34]), ('5', '10', '20', '34'), title = "Long read coverage", loc='lower right')
from matplotlib.lines import Line2D
#axs[1].legend(('Blackbird', 'PBSV', 'Sniffles'), loc='upper right')
legend_elements = [Line2D([0], [0], marker='o', color='w', label='Blackbird',
                          markerfacecolor='red', markersize=15),
                           Line2D([0], [0], marker='o', color='w', label='PBSV',
                          markerfacecolor='g', markersize=15),
                           Line2D([0], [0], marker='o', color='w', label='Sniffles',
                          markerfacecolor='blue', markersize=15)]
axs[1].add_artist(Legend(axs[1],title = "Methods", handles=legend_elements, labels = ["Blackbird", "PBSV", "Sniffles"], loc = 'upper right'))

axs[1].get_legend().legendHandles[0].set_color('black')
axs[1].get_legend().legendHandles[1].set_color('black')
axs[1].get_legend().legendHandles[2].set_color('black')
axs[1].get_legend().legendHandles[3].set_color('black')
#axs[1].get_legend().legendHandles[4].set_color('black')
#axs[1].get_legend().legendHandles[5].set_color('black')


groups = df_del.groupby("Long-Read Coverage")

dd = {}
for name, group in groups:
    print(group)
    #dd[name] = axs[1].scatter(group.Precision, group.Recall, marker = d[name], c = group["SV type"].map(colors), label = d[name])
    dd[name] = axs[0].scatter(group.Precision, group.Recall, marker = marker[name], c = group["Method"].map(colors))
axs[0].set_ylim((0.5,1))
axs[0].set_xlim((0.7,1))
axs[0].set_xlabel("Precision")
axs[0].set_ylabel("Recall")
axs[0].set_title("Deletions")
# Out:
#        Method     SV type Long-Read Coverage  Recall  Precision     F1
# 4   Blackbird  Insertions                  5   0.713      0.935  0.809
# 12       PBSV  Insertions                  5   0.617      0.924  0.738
# 20   Sniffles  Insertions                  5   0.622      0.920  0.742
#        Method     SV type Long-Read Coverage  Recall  Precision     F1
# 5   Blackbird  Insertions                 10   0.738      0.944  0.828
# 13       PBSV  Insertions                 10   0.731      0.913  0.812
# 21   Sniffles  Insertions                 10   0.719      0.912  0.804
#        Method     SV type Long-Read Coverage  Recall  Precision     F1
# 6   Blackbird  Insertions                 20   0.755      0.892  0.817
# 14       PBSV  Insertions                 20   0.753      0.915  0.826
# 22   Sniffles  Insertions                 20   0.740      0.904  0.814
#        Method     SV type Long-Read Coverage  Recall  Precision     F1
# ...

# %%
group["Method"].map(colors)
# Out:
# 3       red
# 9     green
# 15      NaN
# Name: Method, dtype: object

# %%
fig, axs = plt.subplots(2, 3, figsize =(20,10))
font = {'family' : 'normal',
        'size'   : 10}
plt.rc('font', **font)
plt.rcParams['figure.dpi'] = 400


df_5 = df_long[(df_long["Long-Read Coverage"] == 5)]
df_10 = df_long[(df_long["Long-Read Coverage"] == 10)]
df_15 = df_long[(df_long["Long-Read Coverage"] == 15)]
df_20 = df_long[(df_long["Long-Read Coverage"] == 20)]
df_25 = df_long[(df_long["Long-Read Coverage"] == 25)]
df_30 = df_long[(df_long["Long-Read Coverage"] == 30)]
print(df_15)

df_5.plot(kind = "bar", ylabel = "Blackbird", ax= axs[0][0], ylim=(0, 1.0), yticks = np.arange(0, 1.01, 0.1), title = "Long read coverage = 5", xlabel = "", rot = 0)
df_10.plot(kind = "bar", ax= axs[0][1], ylim=(0, 1.0), yticks = np.arange(0, 1.01, 0.1), title = "Long read coverage = 10", xlabel = "", rot = 0)
#df_15.set_index("Method").plot(kind = "scatter",x = "Precision", y = "Recall", c = [df_15['SV type']], ax= axs[0][2], ylim=(0, 1.0), yticks = np.arange(0, 1.01, 0.1), title = "Long read coverage = 15", xlabel = "", rot = 0)
#df_20.set_index("SV type").plot(kind = "bar", ylabel = "PBSV", ax= axs[1][0], ylim=(0, 1.0), yticks = np.arange(0, 1.01, 0.1), title = "Long read coverage = 20", xlabel = "", rot = 0)
#df_25.set_index("SV type").plot(kind = "bar", ax= axs[1][1], ylim=(0, 1.0), yticks = np.arange(0, 1.01, 0.1), title = "Long read coverage = 25", xlabel = "", rot = 0)
#df_30.set_index("SV type").plot(kind = "bar", ax= axs[1][2], ylim=(0, 1.0), yticks = np.arange(0, 1.01, 0.1), title = "Long read coverage = 30", xlabel = "", rot = 0)


colors = {'Insertions' : 'red', 'Deletions':'blue'}
d = {"Sniffles" : 'd', "Blackbird" : 's', "PBSV" : 'p'}
groups = df_15.groupby('Method')
dd = {}
for name, group in groups:
    print(name)
    dd[name] = axs[0][2].scatter(group.Precision, group.Recall, marker = d[name], c = group["SV type"].map(colors), label = d[name])

axs[0][2].legend((dd["Blackbird"], dd["PBSV"], dd["Sniffles"]), ('Blackbird', 'PBSV', 'Sniffles'), loc='lower right')
axs[0][2].get_legend().legendHandles[0].set_color('green')
axs[0][2].get_legend().legendHandles[1].set_color('green')
axs[0][2].get_legend().legendHandles[2].set_color('green')

#for name, group in groups:
#    axs[0][2].plot(group.Precision, group.Recall, marker='o', linestyle='', xlim=(0.5,1.0), ylim=(0.5,1.0), ms=12, label=name)
#axs[0][2].legend()

axs[0][0].get_legend().remove()
axs[0][1].get_legend().remove()
#axs[0][2].get_legend().remove()
#axs[1][0].get_legend().remove()
#axs[1][1].get_legend().remove()
#axs[1][2].get_legend().remove()

for ax_vector in axs:
    for ax in ax_vector:
        for container in ax.containers:
            ax.bar_label(container)


fig.show()
# Out:
#        Method     SV type Long-Read Coverage  Recall  Precision     F1
# 2   Blackbird   Deletions                 15   0.836      0.868  0.852
# 5   Blackbird  Insertions                 15   0.773      0.904  0.833
# 9        PBSV   Deletions                 15   0.813      0.955  0.878
# 13       PBSV  Insertions                 15   0.729      0.899  0.805
# 17   Sniffles   Deletions                 15   0.809      0.949  0.873
# 21   Sniffles  Insertions                 15   0.691      0.904  0.784
# Blackbird
# PBSV
# Sniffles
# /var/folders/56/2rbdb8654tbdcvbn4dwlc9mc0000gt/T/ipykernel_64038/1919432450.py:54: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig, axs = plt.subplots(1, 2, figsize =(20,10))
font = {'family' : 'normal',
        'size'   : 10}
plt.rc('font', **font)
plt.rcParams['figure.dpi'] = 400


df_ins = df_long[(df_long["Long-Read Coverage"] == "Insertions")]
df_del = df_long[(df_long["Long-Read Coverage"] == "Deletions")]
colors = {'Blackbird' : 'red', 'Sniffles2':'blue', "PBSV" : 'green'}
marker = {5 : 'd', 10 : 's', 15 : 'p', 20 : '<', 25 : '>', 30 : 'P'}

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df_hg002 = pd.DataFrame(columns = ["Method", "SV type", "Long-Read Coverage",   "Recall", "Precision",  "F1"])
df_hg002 = df_hg002.append({"Method" : "Blackbird", "SV type" : "Deletions", "Long-Read Coverage" : 5, "Precision" : 0.860, "Recall" : 0.793, "F1" : 0.826}, ignore_index = True)
df_hg002 = df_hg002.append({"Method" : "Blackbird", "SV type" : "Deletions", "Long-Read Coverage" : 10, "Precision" : 0.866, "Recall" : 0.829, "F1" : 0.853}, ignore_index = True)
df_hg002 = df_hg002.append({"Method" : "Blackbird", "SV type" : "Insertions", "Long-Read Coverage" : 5, "Precision" : 0.935, "Recall" : 0.713, "F1" : 0.809}, ignore_index = True)
df_hg002 = df_hg002.append({"Method" : "Blackbird", "SV type" : "Insertions", "Long-Read Coverage" : 10, "Precision" : 0.944, "Recall" : 0.738, "F1" : 0.828}, ignore_index = True)


df_hg002= df_hg002.append({"Method" : "PBSV", "SV type" : "Deletions", "Long-Read Coverage" : 5, "Precision" : 0.906, "Recall" : 0.694, "F1" : 0.786}, ignore_index = True)
df_hg002= df_hg002.append({"Method" : "PBSV", "SV type" : "Deletions", "Long-Read Coverage" : 10, "Precision" : 0.906, "Recall" : 0.812, "F1" : 0.857}, ignore_index = True)
df_hg002 = df_hg002.append({"Method" : "PBSV", "SV type" : "Insertions", "Long-Read Coverage" : 5, "Precision" : 0.924, "Recall" : 0.617, "F1" : 0.738}, ignore_index = True)
df_hg002 = df_hg002.append({"Method" : "PBSV", "SV type" : "Insertions", "Long-Read Coverage" : 10, "Precision" : 0.913, "Recall" : 0.731, "F1" : 0.812}, ignore_index = True)

df_hg002 = df_hg002.append({"Method" : "Sniffles", "SV type" : "Deletions", "Long-Read Coverage" : 5, "Precision" : 0.886, "Recall" : 0.688, "F1" : 0.774}, ignore_index = True)
df_hg002 = df_hg002.append({"Method" : "Sniffles", "SV type" : "Deletions", "Long-Read Coverage" : 10, "Precision" : 0.888, "Recall" : 0.796, "F1" : 0.839}, ignore_index = True)

df_hg002 = df_hg002.append({"Method" : "Sniffles", "SV type" : "Insertions", "Long-Read Coverage" : 5, "Precision" : 0.920, "Recall" : 0.622, "F1" : 0.742}, ignore_index = True)
df_hg002 = df_hg002.append({"Method" : "Sniffles", "SV type" : "Insertions", "Long-Read Coverage" : 10, "Precision" : 0.912, "Recall" : 0.719, "F1" : 0.804}, ignore_index = True)

# %%
fig, axs = plt.subplots(1, 2, figsize =(20,10))
font = {'family' : 'normal',
        'size'   : 10}
plt.rc('font', **font)
plt.rcParams['figure.dpi'] = 400


df_ins = df_hg002[(df_hg002["SV type"] == "Insertions")]
df_del = df_hg002[(df_hg002["SV type"] == "Deletions")]
colors = {'Blackbird' : 'red', 'Sniffles':'blue', "PBSV" : 'green'}
marker = {5 : 'd', 10 : 's'}


groups = df_ins.groupby("Long-Read Coverage")

dd = {}
for name, group in groups:
    print(group)
    #dd[name] = axs[1].scatter(group.Precision, group.Recall, marker = d[name], c = group["SV type"].map(colors), label = d[name])
    dd[name] = axs[1].scatter(group.Precision, group.Recall, marker = marker[name], c = group["Method"].map(colors))
axs[1].set_ylim((0.5,1))
axs[1].set_xlim((0.7,1))
axs[1].set_xlabel("Precision")
axs[1].set_ylabel("Recall")
axs[1].set_title("Insertions")
from matplotlib.legend import Legend

axs[1].legend((dd[5], dd[10]), ('5', '10'), title = "Long read coverage", loc='lower right')
from matplotlib.lines import Line2D
#axs[1].legend(('Blackbird', 'PBSV', 'Sniffles'), loc='upper right')
legend_elements = [Line2D([0], [0], marker='o', color='w', label='Blackbird',
                          markerfacecolor='red', markersize=15),
                           Line2D([0], [0], marker='o', color='w', label='PBSV',
                          markerfacecolor='g', markersize=15),
                           Line2D([0], [0], marker='o', color='w', label='Sniffles',
                          markerfacecolor='blue', markersize=15)]
axs[1].add_artist(Legend(axs[1],title = "Methods", handles=legend_elements, labels = ["Blackbird", "PBSV", "Sniffles"], loc = 'upper right'))

axs[1].get_legend().legendHandles[0].set_color('black')
axs[1].get_legend().legendHandles[1].set_color('black')
#axs[1].get_legend().legendHandles[2].set_color('black')
#axs[1].get_legend().legendHandles[3].set_color('black')
#axs[1].get_legend().legendHandles[4].set_color('black')
#axs[1].get_legend().legendHandles[5].set_color('black')


groups = df_del.groupby("Long-Read Coverage")

dd = {}
for name, group in groups:
    print(group)
    #dd[name] = axs[1].scatter(group.Precision, group.Recall, marker = d[name], c = group["SV type"].map(colors), label = d[name])
    dd[name] = axs[0].scatter(group.Precision, group.Recall, marker = marker[name], c = group["Method"].map(colors))
axs[0].set_ylim((0.5,1))
axs[0].set_xlim((0.7,1))
axs[0].set_xlabel("Precision")
axs[0].set_ylabel("Recall")
axs[0].set_title("Deletions")
# Out:
#        Method     SV type Long-Read Coverage  Recall  Precision     F1
# 2   Blackbird  Insertions                  5   0.713      0.935  0.809
# 6        PBSV  Insertions                  5   0.617      0.924  0.738
# 10   Sniffles  Insertions                  5   0.622      0.920  0.742
#        Method     SV type Long-Read Coverage  Recall  Precision     F1
# 3   Blackbird  Insertions                 10   0.738      0.944  0.828
# 7        PBSV  Insertions                 10   0.731      0.913  0.812
# 11   Sniffles  Insertions                 10   0.719      0.912  0.804
#       Method    SV type Long-Read Coverage  Recall  Precision     F1
# 0  Blackbird  Deletions                  5   0.793      0.860  0.826
# 4       PBSV  Deletions                  5   0.694      0.906  0.786
# 8   Sniffles  Deletions                  5   0.688      0.886  0.774
#       Method    SV type Long-Read Coverage  Recall  Precision     F1
# ...
